# %%
# !pip install retina-face
# !pip install deepface
pass
# Out:
# Requirement already satisfied: retina-face in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (0.0.13)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from retina-face) (9.4.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from retina-face) (2.15.0)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from retina-face) (4.7.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from retina-face) (1.23.5)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from retina-face) (4.7.0.72)
# Requirement already satisfied: six in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from gdown>=3.10.1->retina-face) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from gdown>=3.10.1->retina-face) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from gdown>=3.10.1->retina-face) (4.12.2)
# Requirement already satisfied: filelock in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from gdown>=3.10.1->retina-face) (3.9.0)
# Requirement already satisfied: requests[socks] in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from gdown>=3.10.1->retina-face) (2.28.1)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow>=1.9.0->retina-face) (2.15.0)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (2.15.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (0.2.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (1.14.1)
# Requirement already satisfied: setuptools in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (65.6.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (4.23.4)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (3.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (2.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (1.56.0)
# Requirement already satisfied: packaging in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (22.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (23.5.26)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (0.31.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (0.2.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (2.15.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (4.8.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (0.5.4)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (2.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->retina-face) (2.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (1.26.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (1.7.1)
# Requirement already satisfied: colorama in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tqdm->gdown>=3.10.1->retina-face) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (2.25.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (3.5.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (1.2.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (3.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (0.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (5.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (3.11.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->retina-face) (3.2.2)
# Requirement already satisfied: deepface in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (0.0.80)
# Requirement already satisfied: fire>=0.4.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (0.5.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (0.0.13)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (9.4.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (2.15.0)
# Requirement already satisfied: Deprecated>=1.2.13 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (1.2.14)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (1.23.5)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (1.5.3)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (21.2.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (4.7.0.72)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (2.15.0)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (4.7.1)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (3.0.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from deepface) (4.65.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from Deprecated>=1.2.13->deepface) (1.14.1)
# Requirement already satisfied: six in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from fire>=0.4.0->deepface) (2.4.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from Flask>=1.1.2->deepface) (1.7.0)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from Flask>=1.1.2->deepface) (6.0.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: beautifulsoup4 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: filelock in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from gdown>=3.10.1->deepface) (3.9.0)
# Requirement already satisfied: requests[socks] in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from gdown>=3.10.1->deepface) (2.28.1)
# Requirement already satisfied: packaging in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from gunicorn>=20.1.0->deepface) (22.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from pandas>=0.23.4->deepface) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.15.0)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (65.6.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.15.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.56.0)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (23.5.26)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (4.23.4)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.10.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.5.4)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (16.0.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (4.8.0)
# Requirement already satisfied: colorama in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from importlib-metadata>=3.6.0->Flask>=1.1.2->deepface) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.38.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.25.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.5.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (5.3.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pe256\anaconda3\envs\ml\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.2.2)

# %%
import cv2
from retinaface import RetinaFace
img_path = "./datasets/Wonyoung/1.jpg"
resp = RetinaFace.detect_faces(img_path)
print(resp)
# Out:
# WARNING:tensorflow:From c:\Users\pe256\anaconda3\envs\ml\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# {'face_1': {'score': 0.999681830406189, 'facial_area': [173, 117, 290, 277], 'landmarks': {'right_eye': [215.545, 181.54971], 'left_eye': [264.93472, 195.86566], 'nose': [235.80077, 221.29085], 'mouth_right': [201.15369, 231.16246], 'mouth_left': [246.16557, 243.20117]}}}

# %%
# from google.colab.patches import cv2_imshow
import cv2
from matplotlib import pyplot as plt

img_bgr = cv2.imread(img_path, cv2.IMREAD_COLOR)
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

for people in resp:
  cv2.rectangle(img_rgb, (resp[people]['facial_area'][0],resp[people]['facial_area'][1]), (resp[people]['facial_area'][2], resp[people]['facial_area'][3]), (0,255,0), 3)
  for feature, mark in resp[people]['landmarks'].items():
    # print(f"{feature} {mark}")
    cv2.circle(img_rgb, (int(mark[0]), int(mark[1])), 1, (255,0,0), 4)

# img = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2BGR)

# show using cv2
# cv2_imshow(img)
plt.imshow(img_rgb)
plt.show()

# %%
import matplotlib.pyplot as plt
faces = RetinaFace.extract_faces(img_path = img_path, align = True)
for face in faces:
  plt.imshow(face)
  plt.show()

# %%
from deepface import DeepFace
obj = DeepFace.verify("./datasets/Wonyoung/0.jpg", "./datasets/Wonyoung/4.jpg"
          , model_name = 'ArcFace', detector_backend = 'retinaface')
print(obj["verified"])
# Out:
# 23-12-19 19:51:10 - arcface_weights.h5 will be downloaded to C:\Users\pe256/.deepface/weights/arcface_weights.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: C:\Users\pe256\.deepface\weights\arcface_weights.h5
# 100%|██████████| 137M/137M [01:04<00:00, 2.11MB/s]
# True
